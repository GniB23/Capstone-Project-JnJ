# %% [markdown]
# ## Load data

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
tweet_nolabel = pd.read_csv('tweet_no_label_afterpreprocess.csv')
tweet_original = pd.read_csv('tweets-no-labels.csv')
tweet_nolabel.columns
# Out:
# Index(['Unnamed: 0', 'text', 'query'], dtype='object')

# %%
tweet_nolabel.rename(columns = {'text': 'text_preprocess'},inplace = True)
tweet_nolabel.drop(columns = 'Unnamed: 0', inplace = True)
tweet_nolabel.head()
# Out:
#                                      text_preprocess    query
# 0  timcast joerogan isnt goal beat viru let say a...     #jnj
# 1  ema_new frustrat ema_new jnj ship vaccin made ...     #jnj
# 2  alexandrosandr yorkteachingnh ethicon abby_lan...  ethicon
# 3  jack jennif roll today i love sinc i first lai...     #jnj
# 4  xotonironixo they alway jnj alway hold special...     #jnj

# %%
#Combine two tables
tweet_nolabel = tweet_nolabel.join(tweet_original.text)

# %%
tweet_nolabel.rename(columns = {'text': 'text_original'},inplace = True)

# %%
tweet_nolabel.head()
# Out:
#                                      text_preprocess    query  \
# 0  timcast joerogan isnt goal beat viru let say a...     #jnj
# 1  ema_new frustrat ema_new jnj ship vaccin made ...     #jnj
# 2  alexandrosandr yorkteachingnh ethicon abby_lan...  ethicon
# 3  jack jennif roll today i love sinc i first lai...     #jnj
# 4  xotonironixo they alway jnj alway hold special...     #jnj
#
#                                        text_original
# 0  @Timcast @joerogan Isn’t the goal to beat the ...
# 1  @EMA_News Frustrating @EMA_News #JnJ ships vac...
# 2  @AlexandrosAndre @YorkTeachingNHS @Ethicon @ab...
# 3  Jack and Jennifer had me rolling today. I have...
# 4  @xotonironixo They will always be #JnJ to me a...

# %%
tweet_nolabel['query'].value_counts()
# Out:
# #jnj                  22598
# ethicon                 678
# #bwi                    406
# "ETHICON"               391
# biosense webster         61
# "BIOSENSE WEBSTER"       29
# Name: query, dtype: int64

# %% [markdown]
# ### Null values

# %%
#text_preprocess has null values
tweet_nolabel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24163 entries, 0 to 24162
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   text_preprocess  24130 non-null  object
#  1   query            24163 non-null  object
#  2   text_original    24163 non-null  object
# dtypes: object(3)
# memory usage: 566.4+ KB

# %%
# creating bool series True for NaN values 
bool_series = pd.isnull(tweet_nolabel.text_preprocess) 

# filtering data 
# displaying data only with text_preprocess = NaN 
tweet_nolabel[bool_series]
# Out:
#       text_preprocess               query  \
# 1295              NaN                #jnj
# 3105              NaN                #jnj
# 4254              NaN                #jnj
# 5751              NaN  "BIOSENSE WEBSTER"
# 6209              NaN                #jnj
# 6541              NaN                #jnj
# 6745              NaN                #jnj
# 8532              NaN                #jnj
# 8534              NaN                #jnj
# 8545              NaN                #jnj
# 8549              NaN                #jnj
# 8550              NaN                #jnj
# 8560              NaN                #jnj
# 8791              NaN                #bwi
# 10708             NaN                #jnj
# 15593             NaN                #jnj
# 16901             NaN                #jnj
# 16902             NaN                #jnj
# 16903             NaN                #jnj
# 17386             NaN                #jnj
# 19119             NaN                #jnj
# 19120             NaN                #jnj
# 23070             NaN                #jnj
# 23071             NaN                #jnj
columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   text_preprocess  24130 non-null  object
#  1   query            24130 non-null  object
#  2   text_original    24130 non-null  object
# dtypes: object(3)
# memory usage: 754.1+ KB

# %% [markdown]
# ## Load Blacklist and Whitelist

# %% [markdown]
# ### LDA

# %%
# LDA
import json
with open('lda_blacklist.txt', 'r') as f:
    lda_bl = json.loads(f.read())
lda_bl = set(lda_bl)
len(lda_bl)
# Out:
# 69

# %%
with open('lda_whitelist.txt', 'r') as f:
    lda_wl = json.loads(f.read())
lda_wl = set(lda_wl)
len(lda_wl)
# Out:
# 34

# %% [markdown]
# ### Cluster

# %%
# CLUSTER
with open('kmeans_blacklist.txt', 'r') as f:
    cluster_bl = json.loads(f.read())
cluster_bl = set(cluster_bl)
len(cluster_bl)
# Out:
# 437

# %%
with open('kmeans_whitelist.txt', 'r') as f:
    cluster_wl = json.loads(f.read())
cluster_wl = set(cluster_wl)
len(cluster_wl)
# Out:
# 60

# %% [markdown]
# ### Frequent words

# %%
# FREQUENT WORDS
with open('frequency_blacklist.txt', 'r') as f:
    frequent_bl = json.loads(f.read())
frequent_bl = set(frequent_bl)
len(frequent_bl)
# Out:
# 50

# %%
with open('frequency_whitelist.txt', 'r') as f:
    frequent_wl = json.loads(f.read())
frequent_wl = set(frequent_wl)
len(frequent_wl)
# Out:
# 50

# %% [markdown]
# ## Algorithm
# - initial score = 0
# - For each tweet:
#   - Have words in any whitelist: score+1
#   - Have words in any blacklist: score-1
# - score range: -3 to 3

# %%
def calculate_score(tweet):
    score = 0
    tweet = set(tweet.split())
    
    #whitelist
    if lda_wl.intersection(tweet):
        score += 1
    if cluster_wl.intersection(tweet):
        score += 1
    if frequent_wl.intersection(tweet):
        score += 1

    #blacklist
    if lda_bl.intersection(tweet):
        score -= 1
    if cluster_bl.intersection(tweet):
        score -= 1
    if frequent_bl.intersection(tweet):
        score -= 1    
    
    return score

# %%
length = len(tweet_nolabel)
score = []
for i in range(length):
    score.append(calculate_score(tweet_nolabel.text_preprocess.iloc[i]))

# %%
tweet_nolabel['score']=score
tweet_nolabel.head()
# Out:
#                                          text_preprocess      query  \
# 15840  transvagin mesh lawsuit file after ethicon gyn...  "ETHICON"
# 3639   ethicon royal surrey smoke evacu trial kick jn...    ethicon
# 13275  carrollodea lawyer billmadden pelvic mesh liti...    ethicon
# 15839  ethicon physiomesh case select for bellweth tr...    ethicon
# 15838  nearli 15000 hernia mesh claim file against ba...    ethicon
#
#                                            text_original  score
# 15840  Transvaginal Mesh Lawsuit Filed After Ethicon ...      3
# 3639   Ethicon Royal Surrey Smoke Evacuation trial ki...      3
# 13275  @carrollodea Lawyers'  @BillMadden : "Pelvic M...      3
# 15839  Ethicon Physiomesh Cases Selected For Bellweth...      3
# 15838  Nearly 15,000 Hernia Mesh Claims Filed Against...      3

# %%
tweet_nolabel['score'].value_counts().sort_index(ascending = False)
# Out:
#  3        8
#  2      147
#  1      604
#  0     3815
# -1    10227
# -2     7787
# -3     1542
# Name: score, dtype: int64

# %%
tweet_nolabel['score'].describe()
# Out:
# count    24130.000000
# mean        -1.222752
# std          0.920381
# min         -3.000000
# 25%         -2.000000
# 50%         -1.000000
# 75%         -1.000000
# max          3.000000
# Name: score, dtype: float64

# %%
tweet_nolabel = tweet_nolabel.sort_values(by=['score'], ascending=False)
tweet_nolabel.head(8)
# Out:
#                                          text_preprocess      query  \
# 15840  transvagin mesh lawsuit file after ethicon gyn...  "ETHICON"
# 16649  vigna law group vagin mesh ethicon multidistri...    ethicon
# 13021  jim crumbley receiv ethicon physiomesh implant...    ethicon
# 16909  biosens webster receiv ce mark approv qdot mic...       #jnj
# 3639   ethicon royal surrey smoke evacu trial kick jn...    ethicon
# 15838  nearli 15000 hernia mesh claim file against ba...    ethicon
# 13275  carrollodea lawyer billmadden pelvic mesh liti...    ethicon
# 15839  ethicon physiomesh case select for bellweth tr...    ethicon
#
#                                            text_original  score
# 15840  Transvaginal Mesh Lawsuit Filed After Ethicon ...      3
# 16649  Vigna Law Group: Vaginal Mesh Ethicon Multidis...      3
# 13021  Jim Crumbley received an Ethicon Physiomesh im...      3
# 16909  Biosense Webster receives CE mark approval for...      3
# 3639   Ethicon Royal Surrey Smoke Evacuation trial ki...      3
# 15838  Nearly 15,000 Hernia Mesh Claims Filed Against...      3
# 13275  @carrollodea Lawyers'  @BillMadden : "Pelvic M...      3
# 15839  Ethicon Physiomesh Cases Selected For Bellweth...      3

# %%
#Tweets with highest score
length = 100
for i in range(length):
    print(str(i) + ': ')
    print(tweet_nolabel.text_original.iloc[i])
    print()
# Out:
# 0:
# Transvaginal Mesh Lawsuit Filed After Ethicon Gynecare Prosima Eroded Into Surrounding Tissue
#  https://t.co/TPQQM6oZ0F
#
# 1:
# Vigna Law Group: Vaginal Mesh Ethicon Multidistrict Litigation Update https://t.co/FMSZ7tCJbz
#
# 2:
# Jim Crumbley received an Ethicon Physiomesh implant to repair his incision ventral hernia in July 2014 at a Georgia hospital.
#
# Read more 👉 https://t.co/IEdKvQ6U9O
#
#  #Herniamesh #Hernia #Bellwether https://t.co/GvqCJknPPc
#
# 3:
# Biosense Webster receives CE mark approval for QDOT MICRO ablation catheter https://t.co/HPvKF8izzT #mycompany #jnj
#
# 4:
# Ethicon Royal Surrey Smoke Evacuation trial kick off.... @JNJMedDeviceUKI @Ethicon #smokeevacuation #orsafety #surgicalsmoke https://t.co/37gf71tLxQ
#
# 5:
# Nearly 15,000 Hernia Mesh Claims Filed Against Bard, Ethicon and Atrium in Federal Courts
# https://t.co/tLIJv0qP5k
#
# 6:
# @carrollodea Lawyers'  @BillMadden : "Pelvic Mesh Litigation – Outcome of the Federal Court of Australia Trial in Gill v Ethicon Sàrl (No 5)" Read in link.
# https://t.co/vMHB2YWaem
# #auslaw https://t.co/7UptB48oxH
#
# 7:
# Ethicon Physiomesh Cases Selected For Bellwether Trials Set To Begin in March, June and Sept. 2021
#  https://t.co/wJQ1ftCs2D
#
# 8:
# Liver Surgery – Right Hepatectomy with Microwave Ablation | ETHICON https://t.co/myoXKkmmvT
#
# 9:
# @PeterPitts @USATODAY I can assure you the MILLIONS of Johnson &amp; Johnson mesh victims around the world will NOT trust #JNJ vaccine nor any other products they manufacturer.
# #meshcrimes #pain #hearourvoice
# #meshcampaign #BoycottTheBandaid
#
# 10:
#
# 31:
# Complaint says J&amp;J/Ethicon withheld information about the propensity of mesh products to fail, resulting in injury &amp; complications.
#
# Complaint claims Ethicon has misrepresented the efficacy &amp; safety of the products, intentionally misleading the public.
#
# https://t.co/q0z6etwEmo
#
# 32:
# The correction also contains a link to Prof Abdel-fattah's own declaration of interests. These include receiving money from a number of mesh manufacturers for being a consultant &amp; trainer for mesh manufacturers including Coloplast &amp; JOHNSON &amp; JOHNSON subsidiary Ethicon. https://t.co/Cwvvv3YEDm
#
# 33:
# @meshedupmum @MeshHolly @JuliaCumberlege @chrisharding123 @NHSEngland @ElneilSuzy @vicderbyshire @thismorning @loosewomen Will @realDonaldTrump
# led FRAUDULENT man-made opioid epidemic inflict further INHUMANE treatment upon victims of #HumanExperimentation or weaponized mesh implants?
#
# #BrexitReality #returnwoodytosender #JNJ
# @WB_UK
# @BorisJohnson
# @MattHancock
#
# 34:
# $JNJ's #SerialKillerCEO Alex Gorsky should be in federal prison for 31 children that died on Risperdal, the 100,000 women injured or died due to Gynecare Mesh &amp; the women who got cancer from Johnson &amp; Johnson Baby Powder.
#
# #TheSociopathicBusinessModel
# #FraudFormula #JNJ https://t.co/S0p7i0TY9L
#
# 35:
# @HarleyRouda @realDonaldTrump @MichelleSteelCA His man-made opioid epidemic is FRAUDULENT. #ConflictOfInterest Johnson &amp; Johnson- grants to once prestigious universities for predetermined outcome. JNJ Ethicon responsible for MILLIONS of irreparable injuries from petroleum derived polypropylene mesh implants.
#
# #ShamTrial
#
# 36:
# @ewarren Mesh implant victims INHUMANELY treated &amp; denied access to appropriate pain medication under guise of addiction WONT GO SILENTLY etiher.  #FirstDoNoHarm #CumberlegeReview #JNJ #intellectualbrutality
#
# 37:
# Ethicon, Inc. - Proceed Surgical Mesh - Class 2 Recall, https://t.co/e6eKl1PY4b
#
# 38:
# $JNJ's #SerialKillerCEO Alex Gorsky should be in federal prison for 31 children that died on Risperdal, the 100,000 women injured or died due to Gynecare Mesh &amp; the women who got cancer from Johnson &amp; Johnson Baby Powder.
#
# #TheSociopathicBusinessModel
# #FraudFormula #JNJ https://t.co/S0p7i0TY9L
#
# 39:
# @lisa02594983 KIMBERLY L. ADKINS : new trial concerning liability.
#
# TVT Secur, JNJ Ethicon global mesh implant.
#
# Ethicon had tested Secur on 31 women, showed a 30%
# FAILURE rate, while 60% of the women experienced complications, according to trial documents.
#
# #FDA #Fail #opioidhysteria
#
# 40:
# First Ethicon Hernia Mesh Lawsuit Selected For Bellwether Discovery Phase
# ▸ https://t.co/FyH79nsL2s
#
# #Herniamesh #Hernia #Bellwether https://t.co/fX0DbRetaE
#
# 41:
# 🇦🇺Australia: Judge orders $JnJ @Ethicon Sling Tape &amp; Prolapse #Mesh brochures to say “Mesh Complications are not rare &amp; can occur regardless of surgeon” based on Manufacturers admissions/evidence from the Trial @MeshAwarenessAU @HumanHeadline @IMMDSReview https://t.co/bbkVUIOQY5
#
# 42:
# @JanUrban12 Could it be that mesh was a WEAPONIZED implant? San Diego California testimony revealed JNJ Ethicon sales reps touted mesh as WEAPONRY.
# @AGBecerra @HarleyRouda Victims of mesh medical devices now facing INHUMANE treatment &amp; access to pain medication.
#
# https://t.co/1JZvIbvKiq
#
# 43:
# @Reuters_Health @AnnBoni1 Not to mention Ethicon mesh, litigation mitigation, possibly?
#
# 44:
# J&amp;J is unsuccessful in its final attempt to overturn an Australian pelvic mesh class action verdict:
# #Court #Australia #JNJ #Ethicon #implants #UnitedStates #Canada #Europe #lawyers #litigation #testing #pharmaceutical
# https://t.co/8RZdoKYGPo https://t.co/OnLKI3n6Qe
#
# 45:
# Transvaginal Mesh Recalls, Discontinued Products &amp; FDA Regulation. Did the UK Trials BSUG &amp; RCOG &amp; Hospitals  provide Ethicon #Mesh implant women with IFU Updates &amp; Recall &amp; Withdrawal notices? @Immdsreview @meshcampaign #TVTSecur #SIMS #Prolift https://t.co/3XpoW2UVsD
#
# 46:
# 🇦🇺Australia: Judge orders $JnJ @Ethicon Sling Tape &amp; Prolapse #Mesh brochures to say “Mesh Complications are not rare &amp; can occur regardless of surgeon” based on Manufacturers admissions/evidence from the Trial @MeshAwarenessAU @HumanHeadline @IMMDSReview https://t.co/YR7q71nAIu
#
# 47:
# STRATAFIX Spiral Devices With Antibacterial Protection | Ethicon https://t.co/NWu9sjizC6 via @YouTube
#
# 48:
# Manufacturer, Ethicon own admission "serious harm" https://t.co/TKdkvHdkUA
#
# 49:
# Ethicon Wins Preliminary Injunction In Counterfeit Device Suit
# https://t.co/nSNa2Ewwct
#
# 50:
# Biosense Webster Launches CARTO® 3 System Version 7 and the CARTO PRIME Mapping Module to Advance Treatment of Complex Arrythmias
# https://t.co/jXDSjQFmwI
# #news #pharma #pharmiweb
#
# 51:
# Ethicon Wins Permanent Injunction In Counterfeit Device Suit
# https://t.co/rneqE31eXa
#
# 52:
# Ethicon Laparoscopic Trainer
# https://t.co/9D4Z4VE1a5
# Gerati laparoscopic trainer ethicon and surgical simulator, mainly from advanced, provides training for at least digestive surgical skills at a very low cost. https://t.co/L8Xqb9L7fU
#
# 53:
# Intraoperative quality measures to reduce anastomotic leak. #VirtuallyVinius Monday 21 sept, 16:05h.
# @escp_tweets @EagleEscp @AntoninoSpin @ClinicoUcp @GVAclinic @incliva_iis @JNJInstitute
# Click here to download further info on the Ethicon Symposium
# https://t.co/iFFV3lqy1R
#
# 54:
# @BiosenseWebster Launches CARTO® 3 System Version 7 and the CARTO PRIME Mapping Module to Advance Treatment of Complex Arrhythmias https://t.co/PkswT1ZUXG https://t.co/7RG2o0AnmM
#
# 55:
# Wow the average surgical operation has the same carbon footprint as driving from London to Edinburgh in a petrol car!!!!! Certainly food for thought!!!!! 🌍🌍🌍🌍
# @NorthumbriaNHS @SykesEliot @iainjdmccallum @Ethicon
#
# 56:
# Ethicon launches device to strengthen staple lines https://t.co/866sAhsyUx
#
# 57:
# Ethicon vs Intuitive Surgical - AIA Trial, Termination $ISRG https://t.co/KqAP0gELNw
#
# 58:
# Vicryl Plus Antibacterial 3-0 VCP316H
# (Ethicon)
#
# #apotikgrogolpratama
# #apotikgrogol
# #apotikjakarta
# #apotek
# #vicryl #vicrylplus
# #ethicon
# https://t.co/NONty7FScz https://t.co/cImW7O0zoc
#
# 59:
# @BourierFelix @EPeeps QDOT MICRO® from Biosense Webster
#
# 60:
# Vicryl Plus Antibacterial 4-0  VCP392H
# (Ethicon)
#
# #apotikgrogolpratama
# #apotikgrogol
# #apotikjakarta
# #apotek
# #vicryl #vicrylplus
# #ethicon
# https://t.co/2tzRd8Y6Zt https://t.co/WQHONytMkN
#
# 61:
# Ethicon Skin staplers available. https://t.co/kVFOMllg4G
#
# 62:
# MEGADYNE Soft Tissue Dissector Powered by GEM Technology | Ethicon https://t.co/NEoj1QAb43 via @YouTube
#
# 63:
# Advanced Soft Tissue Closure Techniques in Orthopedic Surgery | Ethicon https://t.co/QiucVd4s2N via @YouTube
#
# 64:
# @jennyshaomd @Ethicon @IntuitiveSurg @COVSharpSafety Devices should have two basic parts. The surgeon interface and the device "job" for lack of a better term. Interfaces can be any size or even custom to surgeon with a universal port for mechanical action. #AWSChat
#
# 65:
# Interested in hearing what leading surgeons are saying and early experiences with ECHELON Staple Line Reinforcement? Join our webinar on Oct 1st at 7pm. Click to register: https://t.co/wA1EIUm1M6
#
# 66:
# Closing the loop on this...had some congestion, fatigue, weird hip pain for a few nights, and lost taste/smell for 10 days. So, either my 9 month old #JNJ vaccine did its job or #Covid_19 is just another virus. 🤔
#
# 67:
# Foriegn policy?
# EUTHANASIA of European citizens irreparably harmed by JNJ mesh implants?
#
# #SilentNoMore
# #WarOnDrugs #ConflictOfInterest #JNJ #opioids #painpatientsvote
# #Election2020 https://t.co/McgGU1VKMj
#
# 68:
# Buoniello v. Ethicon Women's Health &amp; Urology
#
# Only Warranty Breach, Unjust Enrichment, NIED Claims Dismissed in Suit Over Mesh Device
#
# #law
#
# https://t.co/1eNFVDS4fV
#
# 69:
# Radio-frequency  based catheter ablation HERMOCOOL SMARTTOUCH SF Ablation Catheter by @BiosenseWebster receive #FDA approval for the treatment of persistent #atrialfibrillation
# https://t.co/14sFtvejAz
#
# 70:
# Fact checkers on social media is funded by .. #JNJ the same manufacturers of #mesh.  What’s not to trust? https://t.co/M5KPLnENLK
#
# 71:
# What’s your buttress made of? ECHELON ENDOPATH™ Staple Line Reinforcement uses the same trusted materials as VICRYL® and PDS® sutures. https://t.co/GeMJRDdgf7 https://t.co/8BtcwkBbax
#
# 72:
# What more can we do to reduce the risk of #orthopaedic joint replacement infection? Join Dr. Koji Yamada, who provides perspective on antimicrobial prophylaxis and evidence-based bundles for preventing #SSI. Register here: https://t.co/6IEmni8ty3 https://t.co/h672iRIfrN
#
# 73:
# @Ethicon launches Echelon Endopath SLR buttress solution - device designed for ease of use &amp; delivers seamless buttress experience from start to finish, prevents slipping, twisting, sliding or bunching &amp; provides greater stability when manipulating tissue
#  https://t.co/B9KaQOiRMy https://t.co/jdvIEAlQed
#
# 74:
# New INDEPENENT CLINICAL STUDY demonstrated a 1.7% anastomotic leak rate w/ ECHELON CIRCULAR™ a significant reduction vs manual staplers: https://t.co/KYOJ2FWX1e. Learn about Gripping Surface &amp; 3D Stapling Technology: https://t.co/eUYzYYNqEO. 1st of a forthcoming body of evidence https://t.co/lnVCI1vfoR
#
# 75:
# @jennyshaomd @YewandeAlimiMD @SUBiodesign @Medtronic @Ethicon Not around anymore :(  The Technology and Value Assessment Committee (TAVAC) is the latest home for all things SAGES ergonomic.
#
# 76:
# @Ethicon Launches ECHELON ENDOPATH Staple Line Reinforcement: Reduces Complications Associated with Bariatric, Thoracic and General Surgical Procedures https://t.co/PpvvtkFfYL https://t.co/a6Ml5oOYZD
#
# 77:
# @YewandeAlimiMD @SUBiodesign @Medtronic @Ethicon SAGES started an Ergonomics Task Force waaaaay back in 1994. We've chewed over a lot of this ground and it's frustrating (enraging) to see the lack of progress especially given the available data. #AWSChat
#
# The universal device concept comes from fencing grips :) https://t.co/0fqF0MAZlb
#
# 78:
# The Pennsylvania Supreme Court upheld a $12.5 million verdict awarded to an Indiana woman who accused Johnson &amp; Johnson subsidiary Ethicon of making defective pelvic mesh that injured her. @brenpiers https://t.co/Wq6dDn8H6D ($) https://t.co/g1KdaiMnJk
#
# 79:
# 🇦🇺: Johnson &amp; Johnson lost Pelvic #Mesh Class Action in Australia @Reuters
#
# 1,000s more, suffer 🌎 #Ethicon #JnJ #Trial
#
# @MeshAwarenessAU @MeshCampaign @nswpmsg @FIGOHQ @ICIJorg @RCObsGyn @BAUSurology @ICIJorg @SWEMeshSupport @Marie1902 @STOPMallaTOT #Gyn https://t.co/0AJvqcwvRN
#
# 80:
# Does ANY Of The MESH DISTRIBUTORS CARE About The Damage MESH PLASTIC Has Caused Multitudes Of Patients WorldWide ? BARD, Boston Scientific, AVAULTA, Ethicon &amp; Numerous Other Manufacturers &amp; Distributors Of MESH ! This Includes The Drs Whom Were PAIDOFF To Implant MESH PLASTIC 🩸 https://t.co/DpUJQJI7Cr
#
# 81:
# Biosense Webster Receives FDA Approval for THERMOCOOL SMARTTOUCH® SF Ablation Catheter for the Treatment of Persistent Atrial Fibrillation https://t.co/sTlCLPQpM8
#
# 82:
# @RealErinCruz Our disabled Veterans &amp; irreparable harmed citizens from defective medical devices DESERVE humane treatment &amp; access to appropriate pain medication.
#  #fakeopioidcrisis #shamlitigation #JNJ
# #mafiamedicine
#
# 83:
# @DebHaalandNM Human experimentation &amp; genocide occuring in 21st Century. @latimes
#
# #opioids #WarOnDrugs #ConflictOfInterest #JNJ #implants #mesh #FDAfail
# #eugenics
#
# https://t.co/NoShL4rFWO
#
# 84:
# Here @josoriomd speaks on the promising Q-FFICIENCY trial results of the new ablation catheter—the QDot Micro Catheter (Biosense Webster)
#
# Read the feature below:
# https://t.co/0TyY1D0VLY
#
# #ablation #caridac #research #devices #catheter
#
# 85:
# Who are the leading key players in the Suction Irrigator Market?
# Key players : @Ethicon @Medtronic @richardwolffedc
# @bbraun_com @getolympus @LiNAMedical @ConMedAirSeal @KARLSTORZUro
# #Medical #medicaldevices #device #healthcare #health
# Read more: https://t.co/pQDIkSl3Qz https://t.co/OIwzm2F4R0
#
# 86:
# Johnson &amp; Johnson should have paused #Mesh when women reported complications. By not doing so, thousands of women worldwide are suffering from irreparable damage. Shame on #JNJ
#
# 87:
# First Patients in Europe Treated with Biosense Webster VARIPULSE® AF Catheter https://t.co/L1eajXeAir #MedDevice
#
# 88:
# Same pharmaceutical giant behind the man-made opioid crisis - subsidiary manufacturer of experimental permanent petroleum derived plastic mesh implants.
#
# Win win? Euthanisia by obsolescence of pain medication.
#
# #legal #HumanRights #RightToHealth #ChemicalShitStorm #Opioids #JNJ https://t.co/jlmRlqqH8w https://t.co/S7z4cqFvIo
#
# 89:
# Our initial experience with Echelon Circular powered stapler shows that it could have a positive impact in reducing AL rates in left-sided colorectal anastomosis.@ClinicoUcp @GVAclinic @incliva_iis @TechColoproctol #colorectalsurgery #reduceleaks #Ethicon https://t.co/LGzMMBIFuk https://t.co/gyqP4ilaAq
#
# 90:
# During trial over vaginal mesh, Ethicon sales manager says reps not pushy | Northern California Record https://t.co/vNxNT6p2fW
#
# 91:
# J&amp;J destroyed thousands of files on vaginal mesh implants, judge says - https://t.co/6VonG8Moxd   So DID Boston Scientific, BARD, Ethicon, Avaulta &amp; Others, Doctors, Hospitals ALL “FAILED” Patients ... So DID The FDA, CDC, NIH, WHO. #MESH Is DANGEROUS  https://t.co/sABzD7JVHM
#
# 92:
# Ethicon Physio Hernia Mesh was recalled in 2016 for failing at higher rates than other mesh. Contact Thornton Law Firm’s drug &amp; medical device Attorney Marilyn McGoldrick at 1-888-341-1405 for a free consultation https://t.co/HZaddXKBTX #herniamesh #mesh #surgicalmesh #PhysioMesh
#
# 93:
# @SAGES_Updates I dream about the day when devices can be adjustable for ANY hand size! #Surgonomics #AWSChat @Ethicon @IntuitiveSurg @COVSharpSafety
#
# 94:
# This is a true problem that impacts surgeon longevity. We must incorporate techniques to improve surgeon ergonomics into our daily practice, in how we teach our trainees, and how we approach design for surgical instruments! @GeetaLalMD @Medtronic @Ethicon @IntuitiveSurg https://t.co/Ix7yw8zbYD
#
# 95:
# First Patients in Europe Treated with Biosense Webster VARIPULSE® Catheter for Atrial Fibrillation Treatment | J&amp;J Medical Devices https://t.co/oHsANAgsWq
#
# 96:
# Ethicon Physio Hernia Mesh was recalled in 2016 for failing at higher rates than other mesh. Contact Thornton Law Firm’s drug &amp; medical device Attorney Marilyn McGoldrick at 1-888-341-1405 for a free consultation https://t.co/HZaddXKBTX #herniamesh #mesh #surgicalmesh #PhysioMesh
#
# 97:
# Ethicon Physio Hernia Mesh was recalled in 2016 for failing at higher rates than other mesh. Contact Thornton Law Firm’s drug &amp; medical device Attorney Marilyn McGoldrick at 1-888-341-1405 for a free consultation https://t.co/HZaddXKBTX #herniamesh #mesh #surgicalmesh #PhysioMesh
#
# 98:
# @realDonaldTrump @FDA 2012 - ETHICON
# Product Recalled - Gynecare Prolift Kit, Gynecare Prolift+M Kit, Gynecare TVT Secure and Gynecare Prosima Pelvic Floor Repair System Kit (transvaginal mesh implants)
# Reason for Recall - Perforation of organs; vaginal bleeding and scarring; mesh erosion; severe pain
#
# 99:
# @cynthiabydesign @CMerandi @AGBecerra Over 80,000 Johnson &amp; Johnson Ethicon mesh victims in California alone. Perhaps millions more if you include the other mesh manufacturers. Opiates WARRANTED &amp; JUSTIFIED.
# @hrw
# #HumanRights #neurmbergcode #HumanGuineaPigs

# %% [markdown]
# ## Algorithm2
# - initial score = 0
# - For each word, if it is in any whitelist, score+1. If it is in any blacklist, score-1.

# %%
def calculate_score_v2(tweet):
    score = 0
    tweet = tweet.split() 
    for t in tweet:
        if t in lda_wl:
            score += 1
        if t in cluster_wl:
            score += 1
        if t in frequent_wl:
            score += 1
        if t in frequent_bl:
            score -= 1
        if t in cluster_bl:
            score -= 1
        if t in lda_bl:
            score -= 1
        #score = score/len(tweet)
    return score

# %%
length = len(tweet_nolabel)
score2 = []
for i in range(length):
    score2.append(calculate_score_v2(tweet_nolabel.text_preprocess.iloc[i]))
tweet_nolabel['score2']=score2
tweet_nolabel.head(20)
# Out:
#                                          text_preprocess             query  \
# 15840  transvagin mesh lawsuit file after ethicon gyn...         "ETHICON"
# 16649  vigna law group vagin mesh ethicon multidistri...           ethicon
# 13021  jim crumbley receiv ethicon physiomesh implant...           ethicon
# 16909  biosens webster receiv ce mark approv qdot mic...              #jnj
# 3639   ethicon royal surrey smoke evacu trial kick jn...           ethicon
# 15838  nearli 15000 hernia mesh claim file against ba...           ethicon
# 13275  carrollodea lawyer billmadden pelvic mesh liti...           ethicon
# 15839  ethicon physiomesh case select for bellweth tr...           ethicon
# 14954  liver surgeri right hepatectomi microwav ablat...           ethicon
# 23415  peterpitt usatoday i assur million johnson amp...              #jnj
# 21446  in jan 2012fda order 30 transvagin mesh manufa...         "ETHICON"
# 19218  judi work ethicon lab qc linda nowak ferguson ...         "ETHICON"
# 18683  johnson johnson institut organ primari total k...              #jnj
# 18684  johnson johnson institut organ primari hip art...              #jnj
# 18685  johnson johnson institut organ revis hip arthr...              #jnj
# 21472  biosensewebst receiv fda approv thermocool sma...  biosense webster
# 18699  brazilian health regul anvisa author resumpt c...              #jnj
# 21462  125 million verdict upheld ethicon mesh victim...           ethicon
# 7991   webinar alert 11421 brendafulm sharehold firm ...           ethicon
# 23362  a statement appear tell doctor expos latest we...           ethicon
#
#                                            text_original  score  score2
# 15840  Transvaginal Mesh Lawsuit Filed After Ethicon ...      3       6
# 16649  Vigna Law Group: Vaginal Mesh Ethicon Multidis...      3       6
# 13021  Jim Crumbley received an Ethicon Physiomesh im...      3       4
# 16909  Biosense Webster receives CE mark approval for...      3       8
# 3639   Ethicon Royal Surrey Smoke Evacuation trial ki...      3       5
# 15838  Nearly 15,000 Hernia Mesh Claims Filed Against...      3       5
# 13275  @carrollodea Lawyers'  @BillMadden : "Pelvic M...      3       6
# 15839  Ethicon Physiomesh Cases Selected For Bellweth...      3       4
# 14954  Liver Surgery – Right Hepatectomy with Microwa...      2       4
# 23415  @PeterPitts @USATODAY I can assure you the MIL...      2       1
# 21446  In Jan 2012🇺🇸FDA ordered over 30 transvaginal ...      2      15
# 19218  Judy worked at Ethicon in lab doing QC. Linda ...      2       0
# 18683  Johnson and Johnson Institute organized Primar...      2       2
# 18684  Johnson and Johnson Institute organized Primar...      2       5
# 18685  Johnson and Johnson Institute organized Revisi...      2       5
# 21472  @BiosenseWebster Receives FDA Approval for THE...      2      15
# 18699  Brazilian health regulator Anvisa has authoriz...      2      -1
# 21462  $12.5 million #verdict upheld for Ethicon mesh...      2       5
# 7991   Webinar alert - 1/14/21 - @BrendaFulmer, a sha...      2      10
# 23362  A statement appeared telling doctors, “you wil...      2       8

# %%
tweet_nolabel.sort_values(by=['score2'], ascending=False)
# Out:
#                                          text_preprocess             query  \
# 23364  janurban 12 could mesh weapon implant san dieg...           ethicon
# 23510  fda clear biosens webster thermocool smarttouc...  biosense webster
# 21464  biosens webster receiv fda approv thermocool s...  biosense webster
# 3705   radiofrequ base cathet ablat hermocool smartto...  biosense webster
# 21472  biosensewebst receiv fda approv thermocool sma...  biosense webster
# ...                                                  ...               ...
# 8189   ive never profit now time snt pola coin inu in...              #jnj
# 18557  ive never profit now time snt pola coin inu in...              #jnj
# 18555  ive never profit now time snt pola coin inu in...              #jnj
# 16573  ive never profit now time snt pola coin inu in...              #jnj
# 15356  ive never profit now time snt pola coin inu in...              #jnj
#
#                                            text_original  score  score2
# 23364  @JanUrban12 Could it be that mesh was a WEAPON...      2      20
# 23510  FDA Clears Biosense Webster ThermoCool SmartTo...      2      17
# 21464  Biosense Webster Receives FDA Approval for THE...      2      16
# 3705   Radio-frequency  based catheter ablation HERMO...      2      15
# 21472  @BiosenseWebster Receives FDA Approval for THE...      2      15
# ...                                                  ...    ...     ...
# 8189   I've never been profitable before. Now is the ...     -3     -88
# 18557  I've never been profitable before. Now is the ...     -3     -88
# 18555  I've never been profitable before. Now is the ...     -3     -88
# 16573  I've never been profitable before. Now is the ...     -3     -88
# 15356  I've never been profitable before. Now is the ...     -3     -88
#
# [24130 rows x 5 columns]

# %%
tweet_nolabel.score2.value_counts().sort_index(ascending = False)
# Out:
#  20     1
#  17     1
#  16     1
#  15     4
#  14     2
#        ..
# -81     3
# -84     8
# -86    84
# -87     1
# -88    26
# Name: score2, Length: 76, dtype: int64

# %%
tweet_nolabel.score2.describe()
# Out:
# count    24130.000000
# mean        -6.446871
# std          8.780440
# min        -88.000000
# 25%         -8.000000
# 50%         -4.000000
# 75%         -2.000000
# max         20.000000
# Name: score2, dtype: float64

# %%
#tweet_nolabel.to_csv('corpus.csv')
